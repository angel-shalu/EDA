# %%
import numpy as np    # linear Algebra
import pandas as pd   # data processing, csv file I/O (e.g. pd.read_csv)

# %% [markdown]
# #  Importing pandas and seaborn module

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# plt.style.use("fivethirtyeight")
import warnings
warnings.filterwarnings("ignore")    # this will ignore the warnings.it wont display warning in notebook

# %%
# Importing Iris data set
iris=pd.read_csv(r"C:\Users\shali\Desktop\Nit_Doc\2. JULY\24th, 25th- Advanced EDA project\24th, 25th- Advanced EDA project\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# Displaying Data

iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.drop('Id',axis=1,inplace=True)

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
id(iris)
# Out:
# 2065021883296

# %%
len(iris)
# Out:
# 150

# %%
#  Checking if any there are missing values

iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
iris["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# #  This data set has three varities of Iris plant
# Bar Plot : Here the frequency of the observation is plotted. In this case we are plotting the frequency of the three species in the Iris Dataset

# %%
# Assuming `iris` is your DataFrame
graph = sns.countplot(x="Species", data=iris)
plt.show()

# %%
# Countplot with color palette
graph = sns.countplot(x="Species", data=iris, palette="Set2")
plt.title("Count of Each Species")
plt.xlabel("Species")
plt.ylabel("Count")
plt.show()

# %%
# Set Seaborn and matplotlib style
sns.set_style("whitegrid")  # Options: whitegrid, darkgrid, dark, white, ticks
plt.figure(figsize=(8, 6))  # Set figure size

# Create a countplot with a color palette
graph = sns.countplot(x="Species", data=iris, palette="Set2")

# Set the title with bold font
plt.title("Count of Each Species", fontsize=16, fontweight='bold', color='darkblue')

# Set x-axis label with red color and bold font
plt.xlabel("Species", fontsize=14, fontweight='bold', color='red')

# Set y-axis label with bold font
plt.ylabel("Count", fontsize=14, fontweight='bold')

# Remove unused legend line
# plt.legend  ← this does nothing in countplot without hue

# Show the plot
plt.show()

# %% [markdown]
# # We can see that there are 50 samples each of all the Iris Species in the data set.
# **4. Joint plot: **
# Jointplot is seaborn library specific and can be used to quickly visualize and analyze the relationship between two variables and describe their individual distributions on the same plot.

# %%
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig=sns.jointplot(x="SepalLengthCm",y="SepalWidthCm",data=iris)

# %%
fig=sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=iris, kind="reg")

# %%
fig=sns.jointplot(x='SepalLengthCm',y='SepalWidthCm',kind='hex',data=iris)

# %% [markdown]
# # 5. FacetGrid Plot

# %%
# If you're using Jupyter Notebook, you can uncomment the next line
# %matplotlib inline

# Create the FacetGrid and map scatter plot
g = sns.FacetGrid(iris, hue='Species', height=5)
g.map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm')  # Correct: no x= or y=
g.add_legend()

# # Optional: Set title
# plt.subplots_adjust(top=0.9)
# g.fig.suptitle("Sepal Length vs Sepal Width by Species", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %%
# Load iris dataset if not already loaded
# iris = sns.load_dataset("iris")  # Uncomment if using seaborn's built-in dataset

# Create the FacetGrid
g = sns.FacetGrid(iris, hue='Species', height=5)

# Map the scatter plot (use positional arguments, not x= or y=)
g.map(plt.scatter, 'SepalLengthCm', 'SepalWidthCm')

# Add legend
g.add_legend()

# Show the plot
plt.show()

# %%
# Load Seaborn's built-in iris dataset
iris = sns.load_dataset("iris")

# Create the FacetGrid
g = sns.FacetGrid(iris, hue='species', height=5)
g.map(plt.scatter, 'sepal_length', 'sepal_width').add_legend()

# Show the plot
plt.show()

# %% [markdown]
# # Boxplot
# **6. Boxplot or Whisker plot**
# Box plot was was first introduced in year 1969 by Mathematician John Tukey.Box plot give a statical summary of the features being plotted.Top line represent the max value,top edge of box is third Quartile, middle edge represents the median,bottom edge represents the first quartile value.The bottom most line respresent the minimum value of the feature.The height of the box is called as Interquartile range.The black dots on the plot represent the outlier values in the data.

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris = sns.load_dataset("iris")
plt.figure(figsize=(10, 7))
sns.boxplot(x='species', y='petal_length', data=iris,
            order=['virginica', 'versicolor', 'setosa'],
            linewidth=2.5)
plt.title("Petal Length by Species", fontsize=14, fontweight='bold')
plt.show()

# %%
iris = sns.load_dataset("iris")
iris.rename(columns={
    "species": "Species",
    "petal_length": "PetalLengthCm"
}, inplace=True)

plt.figure(figsize=(10, 7))
sns.boxplot(x='Species', y='PetalLengthCm', data=iris,
            order=['virginica', 'versicolor', 'setosa'],
            linewidth=2.5,palette="Set2")
plt.title("Petal Length by Species", fontsize=14, fontweight='bold')
plt.show()

# %%
iris.boxplot(by="Species", figsize=(12, 6))
plt.suptitle("Boxplot Grouped by Species", fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# # **7. Strip plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set the figure size
plt.figure(figsize=(10, 7))

# Create strip plot
sns.stripplot(
    x='Species',
    y='SepalLengthCm',
    data=iris,
    jitter=True,
    edgecolor='gray',
    size=8,
    palette='winter'
)

# Show the plot
plt.title("Sepal Length by Species (Strip Plot)", fontsize=14, fontweight='bold')
plt.xlabel("Species")
plt.ylabel("Sepal Length (cm)")
plt.show()

# %% [markdown]
# **8. Combining Box and Strip Plots**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Set figure size
plt.figure(figsize=(10, 7))

# Boxplot
sns.boxplot(
    x='Species',
    y='SepalLengthCm',
    data=iris,
    palette='pastel'
)

# Overlay Stripplot
sns.stripplot(
    x='Species',
    y='SepalLengthCm',
    data=iris,
    jitter=True,
    edgecolor='gray',
    size=6,
    palette='pastel'  # Optional: set point color
)

# Title and labels
plt.title("Sepal Length by Species (Boxplot + Stripplot)", fontsize=14, fontweight='bold')
plt.xlabel("Species")
plt.ylabel("Sepal Length (cm)")

# Show plot
plt.show()

# %%
iris.columns
# Out:
# Index(['SepalLengthCm', 'sepal_width', 'petal_length', 'petal_width',
#        'Species'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Seaborn built-in iris dataset
iris = sns.load_dataset("iris")

# Optional: check the column names
# print(iris.columns)

# Rename columns to match your original names if needed
iris.rename(columns={
    "species": "Species",
    "petal_length": "PetalLengthCm"
}, inplace=True)

# Create the plot
plt.figure(figsize=(10, 6))

# Boxplot
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)

# Overlay stripplot
sns.stripplot(x="Species", y="PetalLengthCm", data=iris, jitter=True, edgecolor="gray", ax=ax)

# Set custom box colors
colors = ['green', 'red', 'yellow']

# Modify first 3 box patches
for i, patch in enumerate(ax.patches[:3]):
    patch.set_facecolor(colors[i])
    patch.set_edgecolor('black')
    patch.set_linewidth(2)

# Title
plt.title("Boxplot + Stripplot with Colored Boxes", fontsize=14, fontweight='bold')

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Seaborn built-in iris dataset
iris = sns.load_dataset("iris")

# Rename columns to match expected format
iris.rename(columns={
    "species": "Species",
    "petal_length": "PetalLengthCm"
}, inplace=True)

# Create the figure
plt.figure(figsize=(10, 6))

# Boxplot (unchanged)
ax = sns.boxplot(x="Species", y="PetalLengthCm", data=iris)

# Overlay stripplot with colorful points using palette
sns.stripplot(
    x="Species",
    y="PetalLengthCm",
    data=iris,
    jitter=True,
    edgecolor="gray",
    ax=ax,
    palette="Set1"  # You can also try "Set1", "husl", or "pastel"
)

# Custom box colors
colors = ['green', 'red', 'yellow']
for i, patch in enumerate(ax.patches[:3]):
    patch.set_facecolor(colors[i])
    patch.set_edgecolor('black')
    patch.set_linewidth(2)

# Title
plt.title("Boxplot + Colorful Stripplot", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %% [markdown]
# **9. Violin Plot**
# It is used to visualize the distribution of data and its probability distribution.This chart is a combination of a Box Plot and a Density Plot that is rotated and placed on each side, to show the distribution shape of the data. The thick black bar in the centre represents the interquartile range, the thin black line extended from it represents the 95% confidence intervals, and the white dot is the median.Box Plots are limited in their display of the data, as their visual simplicity tends to hide significant details about how values in the data are distributed

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Seaborn's built-in iris dataset (if not already loaded)
iris = sns.load_dataset("iris")

# Rename columns to match your naming (if necessary)
iris.rename(columns={
    "species": "Species",
    "sepal_length": "SepalLengthCm"
}, inplace=True)

# Get current figure and set size
fig = plt.gcf()
fig.set_size_inches(10, 7)

# Create violin plot
sns.violinplot(x='Species', y='SepalLengthCm', data=iris)

# Set title (optional)
plt.title("Violin Plot of Sepal Length by Species", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Seaborn's built-in iris dataset (if not already loaded)
iris = sns.load_dataset("iris")

# Rename columns to match your naming (if necessary)
iris.rename(columns={
    "species": "Species",
    "sepal_length": "SepalLengthCm"
}, inplace=True)

# Get current figure and set size
fig = plt.gcf()
fig.set_size_inches(10, 7)

# Create violin plot
sns.violinplot(x='Species', y='SepalLengthCm', data=iris, palette="Set1")

# Set title (optional)
plt.title("Violin Plot of Sepal Length by Species", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Seaborn's built-in iris dataset (if not already loaded)
iris = sns.load_dataset("iris")

# Rename columns to match your naming if needed
iris.rename(columns={
    "species": "Species",
    "petal_length": "PetalLengthCm",
    "petal_width": "PetalWidthCm",
    "sepal_length": "SepalLengthCm",
    "sepal_width": "SepalWidthCm"
}, inplace=True)

# Create a figure with 2x2 subplots
plt.figure(figsize=(15, 10))

# Plot 1: Petal Length
plt.subplot(2, 2, 1)
sns.violinplot(x='Species', y='PetalLengthCm', data=iris)
plt.title("Petal Length by Species")

# Plot 2: Petal Width
plt.subplot(2, 2, 2)
sns.violinplot(x='Species', y='PetalWidthCm', data=iris)
plt.title("Petal Width by Species")

# Plot 3: Sepal Length
plt.subplot(2, 2, 3)
sns.violinplot(x='Species', y='SepalLengthCm', data=iris)
plt.title("Sepal Length by Species")

# Plot 4: Sepal Width
plt.subplot(2, 2, 4)
sns.violinplot(x='Species', y='SepalWidthCm', data=iris)
plt.title("Sepal Width by Species")

# Adjust layout to avoid overlap
plt.tight_layout()

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load Seaborn's built-in iris dataset
iris = sns.load_dataset("iris")

# Rename columns to match your naming style
iris.rename(columns={
    "species": "Species",
    "petal_length": "PetalLengthCm",
    "petal_width": "PetalWidthCm",
    "sepal_length": "SepalLengthCm",
    "sepal_width": "SepalWidthCm"
}, inplace=True)

# Set figure size
plt.figure(figsize=(15, 10))

# Plot 1: Petal Length
plt.subplot(2, 2, 1)
sns.violinplot(x='Species', y='PetalLengthCm', data=iris, palette='Set2')
plt.title("Petal Length by Species", fontsize=12, fontweight='bold')

# Plot 2: Petal Width
plt.subplot(2, 2, 2)
sns.violinplot(x='Species', y='PetalWidthCm', data=iris, palette='Set1')
plt.title("Petal Width by Species", fontsize=12, fontweight='bold')

# Plot 3: Sepal Length
plt.subplot(2, 2, 3)
sns.violinplot(x='Species', y='SepalLengthCm', data=iris, palette='husl')
plt.title("Sepal Length by Species", fontsize=12, fontweight='bold')

# Plot 4: Sepal Width
plt.subplot(2, 2, 4)
sns.violinplot(x='Species', y='SepalWidthCm', data=iris, palette='pastel')
plt.title("Sepal Width by Species", fontsize=12, fontweight='bold')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# **10. Pair Plot:**
# A “pairs plot” is also known as a scatterplot, in which one variable in the same data row is matched with another variable's value, like this: Pairs plots are just elaborations on this, showing all variables paired with all the other variables.

# %%
k = sns.pairplot(data=iris,kind='scatter')
plt.show()

# %%
k = sns.pairplot(data=iris,kind='scatter')
sns.set_style("white") 
plt.show()

# %%
k1=sns.pairplot(iris,hue='Species');
plt.show()

# %%
# Remove grid
sns.set_style("white")  # Options: "white", "dark", "whitegrid", etc.

# Create the pairplot
k1 = sns.pairplot(iris, hue='Species')

# Show the plot
plt.show()

# %% [markdown]
# # 11. Heat map
# Heat map is used to find out the correlation between different features in the dataset.High positive or negative value shows that the features have high correlation.This helps us to select the parmeters for machine learning.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset (if not already loaded)
iris = sns.load_dataset("iris")

# Compute correlation matrix (only for numerical columns)
corr_matrix = iris.corr(numeric_only=True)

# Set figure size
fig = plt.gcf()
fig.set_size_inches(10, 7)

# Create heatmap
sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='cubehelix',
    linewidths=1,
    linecolor='k',
    square=True,
    mask=False,
    vmin=-1,
    vmax=1,
    cbar_kws={"orientation": "vertical"},
    cbar=True
)

# Set title
plt.title("Correlation Heatmap of Iris Dataset", fontsize=14, fontweight='bold')

# Show plot
plt.show()

# %% [markdown]
# # 12. Distribution plot:**
# The distribution plot is suitable for comparing range and distribution for groups of numerical data. Data is plotted as value points along an axis. You can choose to display only the value points to see the distribution of values, a bounding box to see the range of values, or a combination of both as shown here.The distribution plot is not relevant for detailed analysis of the data as it deals with a summary of the data distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms
iris.hist(edgecolor='black', linewidth=1.2)

# Adjust figure size
fig = plt.gcf()  # Get current figure
fig.set_size_inches(12, 6)

# Add a main title (optional)
plt.suptitle("Histograms of Iris Dataset Features", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define colors for each feature
colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99']  # soft pastel colors

# Set up the figure
plt.figure(figsize=(12, 6))

# Loop over numeric columns
for i, column in enumerate(iris.select_dtypes(include='number').columns):
    plt.subplot(2, 2, i+1)
    plt.hist(iris[column], bins=15, color=colors[i], edgecolor='black', linewidth=1.2)
    plt.title(column, fontsize=12, fontweight='bold')

# Adjust layout and add a main title
plt.tight_layout()
plt.suptitle("Colorful Histograms of Iris Dataset", fontsize=16, fontweight='bold', y=1.02)

# Show plot
plt.show()

# %% [markdown]
# # 13. Swarm plot**
# It looks a bit like a friendly swarm of bees buzzing about their hive. More importantly, each data point is clearly visible and no data are obscured by overplotting.A beeswarm plot improves upon the random jittering approach to move data points the minimum distance away from one another to avoid overlays. The result is a plot where you can see each distinct data point, like shown in below plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Optional: Rename column if needed
iris.rename(columns={"species": "Species", "petal_length": "PetalLengthCm"}, inplace=True)

# Set Seaborn style
sns.set(style="darkgrid")

# Set figure size
fig = plt.gcf()
fig.set_size_inches(10, 7)

# Create swarm plot
sns.swarmplot(x="Species", y="PetalLengthCm", data=iris)

# Add title (optional)
plt.title("Petal Length by Species (Swarm Plot)", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Optional: Rename column if needed
iris.rename(columns={"species": "Species", "petal_length": "PetalLengthCm"}, inplace=True)

# Set Seaborn style
sns.set(style="darkgrid")

# Set figure size
fig = plt.gcf()
fig.set_size_inches(10, 7)

# Create swarm plot
sns.swarmplot(x="Species", y="PetalLengthCm", data=iris, palette="Set1")

# Add title (optional)
plt.title("Petal Length by Species (Swarm Plot)", fontsize=14, fontweight='bold')

# Show the plot
plt.show()

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=iris, inner=None)
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=iris,color="white", edgecolor="black")
plt.show()

# %%
sns.set(style="whitegrid")
fig=plt.gcf()
fig.set_size_inches(10,7)
ax = sns.violinplot(x="Species", y="PetalLengthCm", data=iris, inner=None, palette="Set2")
ax = sns.swarmplot(x="Species", y="PetalLengthCm", data=iris,color="white", edgecolor="black", palette="Set1")
plt.show()

# %% [markdown]
# # 17 LM Plot

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'PetalLengthCm', 'petal_width',
#        'Species'],
#       dtype='object')

# %%
# Create linear regression plot
fig = sns.lmplot(x="PetalLengthCm", y="PetalWidthCm", data=iris)

# Optional: Set title
plt.title("Linear Regression: Petal Length vs. Petal Width", fontsize=14, fontweight='bold')

# Show plot
plt.show()

# %%
fig = sns.lmplot(x="PetalLengthCm", y="PetalWidthCm", data=iris)
plt.show()

# %% [markdown]
# # 18. FacetGrid**

# %%
sns.FacetGrid(iris, hue="Species", height=6) \
   .map(sns.kdeplot, "PetalLengthCm") \
   .add_legend()
plt.ioff() 
plt.show()

# %% [markdown]
# # 19. Fctor Plot

# %%
# Plot equivalent to factorplot using catplot
sns.catplot(x='Species', y='SepalLengthCm', data=iris, kind='box', height=6, aspect=1.2)
plt.show()

# %% [markdown]
# #  20 Boxen plot

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='Species',y='SepalLengthCm',data=iris)
plt.show()

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig=sns.boxenplot(x='Species',y='SepalLengthCm',data=iris, palette="Set1")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load dataset
iris = sns.load_dataset("iris")

# Set seaborn style
sns.set(style="whitegrid")

# Create figure and set size
fig = plt.gcf()
fig.set_size_inches(10, 7)

# Draw a colorful and unique boxenplot
sns.boxenplot(
    x='species',
    y='sepal_length',
    data=iris,
    palette='Set2',  # Try other palettes: 'Set3', 'pastel', 'coolwarm', 'Spectral'
    linewidth=2
)

# Add title and labels with styling
plt.title("Sepal Length Distribution by Species", fontsize=16, fontweight='bold', color='purple')
plt.xlabel("Species", fontsize=13, fontweight='bold', color='darkblue')
plt.ylabel("Sepal Length (cm)", fontsize=13, fontweight='bold', color='darkgreen')

# Rotate x labels (optional for clarity)
plt.xticks(rotation=15)

# Show grid
plt.grid(True, linestyle='--', alpha=0.6)

# Show plot
plt.show()

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# #  21 KDE plot

# %%
# KDE plot for Sepal Length
sns.kdeplot(data=iris['SepalLengthCm'], fill=True, color='green', linewidth=2)

# Labels and title
plt.title("KDE Plot of Sepal Length", fontsize=14, fontweight='bold')
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Density")
plt.grid(True, linestyle='--', alpha=0.5)

# Show plot
plt.show()

# %% [markdown]
# #  Dashboard

# %%
sns.set_style('darkgrid')
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Boxplot
sns.boxplot(x="Species", y="PetalLengthCm", data=iris, ax=axes[0, 0])

# Violinplot
sns.violinplot(x='Species', y='PetalLengthCm', data=iris, ax=axes[0, 1])

# Stripplot
sns.stripplot(
    x='Species',
    y='SepalLengthCm',
    data=iris,
    jitter=True,
    edgecolor='gray',
    size=8,
    palette='winter',
    orient='v',
    ax=axes[1, 0]
)

# Histogram
axes[1, 1].hist(iris["PetalLengthCm"], bins=30, color='skyblue', edgecolor='black')
axes[1, 1].set_title("Histogram of Petal Length")

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Set dark grid background
sns.set_style('darkgrid')

# Create subplot grid
f, axes = plt.subplots(2, 2, figsize=(15, 15))

# Boxplot with a bright color palette
sns.boxplot(
    x="Species", y="PetalLengthCm",
    data=iris,
    palette="Set2",
    ax=axes[0, 0]
)
axes[0, 0].set_title("Boxplot - Petal Length", fontsize=14, fontweight='bold')

# Violinplot with a different color palette
sns.violinplot(
    x='Species', y='PetalLengthCm',
    data=iris,
    palette="Set3",
    ax=axes[0, 1]
)
axes[0, 1].set_title("Violinplot - Petal Length", fontsize=14, fontweight='bold')

# Stripplot with vibrant color and size
sns.stripplot(
    x='Species', y='SepalLengthCm',
    data=iris,
    jitter=True,
    edgecolor='black',
    linewidth=1,
    size=9,
    palette='cool',
    orient='v',
    ax=axes[1, 0]
)
axes[1, 0].set_title("Stripplot - Sepal Length", fontsize=14, fontweight='bold')

# Histogram with vivid color
axes[1, 1].hist(
    iris["PetalLengthCm"],
    bins=30,
    color='mediumslateblue',
    edgecolor='black',
    alpha=0.8
)
axes[1, 1].set_title("Histogram - Petal Length", fontsize=14, fontweight='bold')
axes[1, 1].set_xlabel("Petal Length (cm)")
axes[1, 1].set_ylabel("Frequency")

# Tight layout for spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# In the dashboard we have shown how to create multiple plots to foam a dashboard using Python.In this plot we have demonstrated how to plot Seaborn and Matplotlib plots on the same Dashboard.
# # **31.Stacked Histogram**

# %%
# Convert 'Species' column to category
iris['Species'] = iris['Species'].astype('category')

# Display the first 5 rows
iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
list1=list()
mylabels=list()
for gen in iris.Species.cat.categories:
    list1.append(iris[iris.Species==gen].SepalLengthCm)
    mylabels.append(gen)
    
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels)
plt.legend()
plt.show()

# %% [markdown]
# With Stacked Histogram we can see the distribution of Sepal Length of Different Species together.This shows us the range of Sepan Length for the three different Species of Iris Flower.
# # Area Plot:**
# Area Plot gives us a visual representation of Various dimensions of Iris flower and their range in dataset.

# %%
# Make sure SepalLengthCm is numeric
iris['SepalLengthCm'] = iris['SepalLengthCm'].astype(float)  # or skip this line if already float

# Show first few rows
print(iris.head())

# Area plot for SepalLengthCm only
iris.plot.area(y='SepalLengthCm', alpha=0.4, figsize=(12, 6))

# Area plot for multiple features
iris.plot.area(
    y=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
    alpha=0.4,
    figsize=(12, 6)
)

plt.show()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0            5.1           3.5            1.4           0.2  setosa
# 1            4.9           3.0            1.4           0.2  setosa
# 2            4.7           3.2            1.3           0.2  setosa
# 3            4.6           3.1            1.5           0.2  setosa
# 4            5.0           3.6            1.4           0.2  setosa

# %%
# Area plot for multiple features
iris.plot.area(
    y=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
    alpha=0.4,
    figsize=(12, 6)
)

plt.show()

# %% [markdown]
# # Distplot:
# It helps us to look at the distribution of a single variable.Kde shows the density of the distribution

# %%
# Distribution plot with KDE and histogram
sns.histplot(iris['SepalLengthCm'], kde=True, bins=20, color='blue', edgecolor='black')

# Show plot
plt.title("Distribution of Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequency")
plt.show()
